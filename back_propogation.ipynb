# %%
# Importing necessary libraries
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# %%
# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Normalize the dataset (0 to 1 range) and reshape input
x_train = x_train.reshape(-1, 28 * 28).astype("float32") / 255.0
x_test = x_test.reshape(-1, 28 * 28).astype("float32") / 255.0

# %%
# Convert labels to one-hot encoding
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
# Build the model
model = Sequential([
    Dense(128, activation='relu', input_shape=(784,)),  # Hidden layer
    Dense(10, activation='softmax')  # Output layer
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compile the model with Adam optimizer and categorical cross-entropy loss
model.compile(optimizer=Adam(), loss=CategoricalCrossentropy(), metrics=['accuracy'])

# %%
# Custom callback to monitor the gradients during backpropagation
class GradientMonitor(tf.keras.callbacks.Callback):
    def on_batch_end(self, batch, logs=None):
        with tf.GradientTape() as tape:
            y_pred = self.model(x_train[:32])  # Use a small batch for gradient computation
            loss = tf.reduce_mean(tf.keras.losses.categorical_crossentropy(y_train[:32], y_pred))

        # Compute gradients
        grads = tape.gradient(loss, self.model.trainable_weights)

        # Print gradient norms to investigate vanishing/exploding gradients
        for i, grad in enumerate(grads):
            print(f"Layer {i} gradient norm: {np.linalg.norm(grad.numpy())}")

# %%
# Train the model and monitor gradients
model.fit(x_train, y_train, epochs=5, batch_size=32, validation_data=(x_test, y_test),
          callbacks=[GradientMonitor()])
# Out:
# Streaming output truncated to the last 5000 lines.
# Layer 1 gradient norm: 0.04950471222400665
# Layer 2 gradient norm: 0.3750082850456238
# Layer 3 gradient norm: 0.03240017965435982
# Layer 0 gradient norm: 0.3981270492076874
# Layer 1 gradient norm: 0.04716205224394798
# Layer 2 gradient norm: 0.35756489634513855
# Layer 3 gradient norm: 0.030836086720228195
#  627/1875 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - accuracy: 0.9880 - loss: 0.0411Layer 0 gradient norm: 0.37733474373817444
# Layer 1 gradient norm: 0.0446072518825531
# Layer 2 gradient norm: 0.3386405110359192
# Layer 3 gradient norm: 0.02915327250957489
# Layer 0 gradient norm: 0.36225149035453796
# Layer 1 gradient norm: 0.042778126895427704
# Layer 2 gradient norm: 0.3248521387577057
# Layer 3 gradient norm: 0.0279499851167202
# Layer 0 gradient norm: 0.34162434935569763
# Layer 1 gradient norm: 0.04028243198990822
# Layer 2 gradient norm: 0.3049949109554291
# Layer 3 gradient norm: 0.02626638486981392
#  630/1875 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - accuracy: 0.9880 - loss: 0.0411Layer 0 gradient norm: 0.32785674929618835
# Layer 1 gradient norm: 0.03854881972074509
# Layer 2 gradient norm: 0.2857103645801544
# Layer 3 gradient norm: 0.02460210770368576
# Layer 0 gradient norm: 0.313713937997818
# Layer 1 gradient norm: 0.036734361201524734
# Layer 2 gradient norm: 0.2688246965408325
# Layer 3 gradient norm: 0.023135066032409668
# Layer 0 gradient norm: 0.2972116470336914
# Layer 1 gradient norm: 0.034729160368442535
# Layer 2 gradient norm: 0.2539259195327759
# Layer 3 gradient norm: 0.021834122017025948
#  633/1875 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - accuracy: 0.9880 - loss: 0.0411Layer 0 gradient norm: 0.28286367654800415
# Layer 1 gradient norm: 0.032981112599372864
# Layer 2 gradient norm: 0.24103353917598724
# Layer 3 gradient norm: 0.020702818408608437
# Layer 0 gradient norm: 0.2670879364013672
# Layer 1 gradient norm: 0.031059997156262398
# Layer 2 gradient norm: 0.22689682245254517
# Layer 3 gradient norm: 0.01944776624441147
# Layer 0 gradient norm: 0.24752213060855865
# Layer 1 gradient norm: 0.028665481135249138
# Layer 2 gradient norm: 0.20969925820827484
# Layer 3 gradient norm: 0.017874175682663918
#  636/1875 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - accuracy: 0.9880 - loss: 0.0411Layer 0 gradient norm: 0.23146621882915497
# Layer 1 gradient norm: 0.026697490364313126
# Layer 2 gradient norm: 0.195481076836586
# Layer 3 gradient norm: 0.01656358502805233
# Layer 0 gradient norm: 0.22353066504001617
# Layer 1 gradient norm: 0.025704704225063324
# Layer 2 gradient norm: 0.18852876126766205
# Layer 3 gradient norm: 0.015890691429376602
# Layer 0 gradient norm: 0.2193530648946762
# Layer 1 gradient norm: 0.02517586201429367
# Layer 2 gradient norm: 0.18478403985500336
# Layer 3 gradient norm: 0.015515009872615337
#  639/1875 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - accuracy: 0.9879 - loss: 0.0411Layer 0 gradient norm: 0.2165246456861496
# Layer 1 gradient norm: 0.024812741205096245
# Layer 2 gradient norm: 0.18224667012691498
# Layer 3 gradient norm: 0.01524418406188488
# Layer 0 gradient norm: 0.2177380621433258
# Layer 1 gradient norm: 0.02492179349064827
# Layer 2 gradient norm: 0.18324486911296844
# Layer 3 gradient norm: 0.015271930955350399
# Layer 0 gradient norm: 0.2178315967321396
# Layer 1 gradient norm: 0.024886546656489372
# Layer 2 gradient norm: 0.18329720199108124
# Layer 3 gradient norm: 0.015207602642476559
#  642/1875 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - accuracy: 0.9879 - loss: 0.0412Layer 0 gradient norm: 0.21792545914649963
# Layer 1 gradient norm: 0.02486180141568184
# Layer 2 gradient norm: 0.18335850536823273
# Layer 3 gradient norm: 0.015144860371947289
# Layer 0 gradient norm: 0.2184184491634369
# Layer 1 gradient norm: 0.024893946945667267
# Layer 2 gradient norm: 0.1838652491569519
# Layer 3 gradient norm: 0.015122584998607635
#  644/1875 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - accuracy: 0.9879 - loss: 0.0412Layer 0 gradient norm: 0.22005948424339294
# Layer 1 gradient norm: 0.02508505806326866
# Layer 2 gradient norm: 0.1866195946931839
# Layer 3 gradient norm: 0.015308557078242302
# Layer 0 gradient norm: 0.2228204607963562
# Layer 1 gradient norm: 0.025387533009052277
# Layer 2 gradient norm: 0.1892704963684082
# Layer 3 gradient norm: 0.015479881316423416
# Layer 0 gradient norm: 0.22492577135562897
# Layer 1 gradient norm: 0.02561078406870365
# Layer 2 gradient norm: 0.19142059981822968
# Layer 3 gradient norm: 0.015614903531968594
#  647/1875 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - accuracy: 0.9879 - loss: 0.0412Layer 0 gradient norm: 0.2237425148487091
# Layer 1 gradient norm: 0.025466499850153923
# Layer 2 gradient norm: 0.19181470572948456
# Layer 3 gradient norm: 0.015576970763504505
# Layer 0 gradient norm: 0.22670389711856842
# Layer 1 gradient norm: 0.025783345103263855
# Layer 2 gradient norm: 0.1945781111717224
# Layer 3 gradient norm: 0.01576811820268631
# Layer 0 gradient norm: 0.22953808307647705
# Layer 1 gradient norm: 0.02609250694513321
# Layer 2 gradient norm: 0.19712330400943756
# Layer 3 gradient norm: 0.015936952084302902
#  650/1875 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - accuracy: 0.9879 - loss: 0.0412Layer 0 gradient norm: 0.23264282941818237
# Layer 1 gradient norm: 0.026435766369104385
# Layer 2 gradient norm: 0.19987305998802185
# Layer 3 gradient norm: 0.01612873189151287
# Layer 0 gradient norm: 0.23738539218902588
# Layer 1 gradient norm: 0.02698717825114727
# Layer 2 gradient norm: 0.2042084038257599
# Layer 3 gradient norm: 0.01646941900253296
# Layer 0 gradient norm: 0.2408340573310852
# Layer 1 gradient norm: 0.027396677061915398
# Layer 2 gradient norm: 0.20742060244083405
# Layer 3 gradient norm: 0.016734937205910683
#  653/1875 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - accuracy: 0.9879 - loss: 0.0412Layer 0 gradient norm: 0.24015715718269348
# Layer 1 gradient norm: 0.02732137218117714
# Layer 2 gradient norm: 0.20663322508335114
# Layer 3 gradient norm: 0.0166658665984869
# Layer 0 gradient norm: 0.2422807216644287
# Layer 1 gradient norm: 0.027616292238235474
# Layer 2 gradient norm: 0.20838741958141327
# Layer 3 gradient norm: 0.016860218718647957
# Layer 0 gradient norm: 0.24760696291923523
# Layer 1 gradient norm: 0.028244277462363243
# Layer 2 gradient norm: 0.21191370487213135
# Layer 3 gradient norm: 0.01721430942416191
#  656/1875 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - accuracy: 0.9879 - loss: 0.0412Layer 0 gradient norm: 0.24793896079063416
# Layer 1 gradient norm: 0.028342710807919502
# Layer 2 gradient norm: 0.21335004270076752
# Layer 3 gradient norm: 0.017361802980303764
# Layer 0 gradient norm: 0.2500040829181671
# Layer 1 gradient norm: 0.028627512976527214
# Layer 2 gradient norm: 0.21512337028980255
# Layer 3 gradient norm: 0.017530353739857674
# Layer 0 gradient norm: 0.25310978293418884
# Layer 1 gradient norm: 0.029021846130490303
# Layer 2 gradient norm: 0.21752475202083588
# Layer 3 gradient norm: 0.01782229356467724
#  659/1875 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - accuracy: 0.9879 - loss: 0.0412Layer 0 gradient norm: 0.251409113407135
# Layer 1 gradient norm: 0.028842495754361153
# Layer 2 gradient norm: 0.21560445427894592
# Layer 3 gradient norm: 0.017716621980071068
# Layer 0 gradient norm: 0.24729640781879425
# Layer 1 gradient norm: 0.028451792895793915
# Layer 2 gradient norm: 0.2150757610797882
# Layer 3 gradient norm: 0.01773281767964363
# Layer 0 gradient norm: 0.2521413266658783
# Layer 1 gradient norm: 0.028995776548981667
# Layer 2 gradient norm: 0.21570837497711182
# Layer 3 gradient norm: 0.017880165949463844
#  662/1875 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - accuracy: 0.9879 - loss: 0.0413Layer 0 gradient norm: 0.25380057096481323
# Layer 1 gradient norm: 0.02924341894686222
# Layer 2 gradient norm: 0.21701568365097046
# Layer 3 gradient norm: 0.018072662875056267
# Layer 0 gradient norm: 0.2587036192417145
# Layer 1 gradient norm: 0.02991834655404091
# Layer 2 gradient norm: 0.222425177693367
# Layer 3 gradient norm: 0.018622197210788727
# Layer 0 gradient norm: 0.2647159695625305
# Layer 1 gradient norm: 0.030678967013955116
# Layer 2 gradient norm: 0.22756637632846832
# Layer 3 gradient norm: 0.019139019772410393
#  665/1875 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.9879 - loss: 0.0413Layer 0 gradient norm: 0.2756560146808624
# Layer 1 gradient norm: 0.0321008674800396
# Layer 2 gradient norm: 0.228568896651268
# Layer 3 gradient norm: 0.0192869883030653
# Layer 0 gradient norm: 0.25795477628707886
# Layer 1 gradient norm: 0.029950151219964027
# Layer 2 gradient norm: 0.22833439707756042
# Layer 3 gradient norm: 0.019317852333188057
# Layer 0 gradient norm: 0.2577846646308899
# Layer 1 gradient norm: 0.029983261600136757
# Layer 2 gradient norm: 0.22795626521110535
# Layer 3 gradient norm: 0.019358858466148376
#  668/1875 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.9879 - loss: 0.0413Layer 0 gradient norm: 0.2597687542438507
# Layer 1 gradient norm: 0.030267946422100067
# Layer 2 gradient norm: 0.22960153222084045
# Layer 3 gradient norm: 0.019566694274544716
# Layer 0 gradient norm: 0.2633034884929657
# Layer 1 gradient norm: 0.03071800246834755
# Layer 2 gradient norm: 0.2323518991470337
# Layer 3 gradient norm: 0.019846638664603233
# Layer 0 gradient norm: 0.2618368864059448
# Layer 1 gradient norm: 0.03050839528441429
# Layer 2 gradient norm: 0.2329055517911911
# Layer 3 gradient norm: 0.019930362701416016
#  671/1875 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.9879 - loss: 0.0413Layer 0 gradient norm: 0.2624340355396271
# Layer 1 gradient norm: 0.03056883066892624
# Layer 2 gradient norm: 0.23280325531959534
# Layer 3 gradient norm: 0.01993284933269024
# Layer 0 gradient norm: 0.2628149390220642
# Layer 1 gradient norm: 0.030621659010648727
# Layer 2 gradient norm: 0.23224182426929474
# Layer 3 gradient norm: 0.019889742136001587
# Layer 0 gradient norm: 0.26295459270477295
# Layer 1 gradient norm: 0.03070032224059105
# Layer 2 gradient norm: 0.23047666251659393
# Layer 3 gradient norm: 0.019739704206585884
#  674/1875 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.9879 - loss: 0.0413Layer 0 gradient norm: 0.25709226727485657
# Layer 1 gradient norm: 0.029984673485159874
# Layer 2 gradient norm: 0.22575435042381287
# Layer 3 gradient norm: 0.019310327246785164
# Layer 0 gradient norm: 0.25498953461647034
# Layer 1 gradient norm: 0.029696857556700706
# Layer 2 gradient norm: 0.22459453344345093
# Layer 3 gradient norm: 0.019156597554683685
# Layer 0 gradient norm: 0.2619365453720093
# Layer 1 gradient norm: 0.030507564544677734
# Layer 2 gradient norm: 0.23092594742774963
# Layer 3 gradient norm: 0.01967075653374195
#  677/1875 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.9879 - loss: 0.0413Layer 0 gradient norm: 0.2683870494365692
# Layer 1 gradient norm: 0.03126052767038345
# Layer 2 gradient norm: 0.23788711428642273
# Layer 3 gradient norm: 0.020188234746456146
# Layer 0 gradient norm: 0.2695046365261078
# Layer 1 gradient norm: 0.03137105330824852
# Layer 2 gradient norm: 0.2438509613275528
# Layer 3 gradient norm: 0.020619340240955353
# Layer 0 gradient norm: 0.27528226375579834
# Layer 1 gradient norm: 0.03202064707875252
# Layer 2 gradient norm: 0.2493552416563034
# Layer 3 gradient norm: 0.02101229503750801
#  680/1875 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.9878 - loss: 0.0413Layer 0 gradient norm: 0.2801761329174042
# Layer 1 gradient norm: 0.032572221010923386
# Layer 2 gradient norm: 0.2540872097015381
# Layer 3 gradient norm: 0.021339669823646545
# Layer 0 gradient norm: 0.2850204110145569
# Layer 1 gradient norm: 0.033077627420425415
# Layer 2 gradient norm: 0.25714120268821716
# Layer 3 gradient norm: 0.02151106670498848
# Layer 0 gradient norm: 0.2882291376590729
# Layer 1 gradient norm: 0.033440619707107544
# Layer 2 gradient norm: 0.26143714785575867
# Layer 3 gradient norm: 0.02179739996790886
#  683/1875 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.9878 - loss: 0.0413Layer 0 gradient norm: 0.2910430133342743
# Layer 1 gradient norm: 0.03375321254134178
# Layer 2 gradient norm: 0.26463425159454346
# Layer 3 gradient norm: 0.022015515714883804
# Layer 0 gradient norm: 0.29289308190345764
# Layer 1 gradient norm: 0.033998746424913406
# Layer 2 gradient norm: 0.26675546169281006
# Layer 3 gradient norm: 0.022144723683595657
# Layer 0 gradient norm: 0.2927999198436737
# Layer 1 gradient norm: 0.033970821648836136
# Layer 2 gradient norm: 0.26730138063430786
# Layer 3 gradient norm: 0.022133473306894302
#  686/1875 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.9878 - loss: 0.0414Layer 0 gradient norm: 0.2924841344356537
# Layer 1 gradient norm: 0.03391338884830475
# Layer 2 gradient norm: 0.2676043212413788
# Layer 3 gradient norm: 0.02210841327905655
# Layer 0 gradient norm: 0.3107410967350006
# Layer 1 gradient norm: 0.036147430539131165
# Layer 2 gradient norm: 0.26775455474853516
# Layer 3 gradient norm: 0.02207518182694912
# Layer 0 gradient norm: 0.3118908405303955
# Layer 1 gradient norm: 0.03628113120794296
# Layer 2 gradient norm: 0.26941853761672974
# Layer 3 gradient norm: 0.02215835452079773
#  689/1875 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.9878 - loss: 0.0414Layer 0 gradient norm: 0.3153247833251953
# Layer 1 gradient norm: 0.03664021193981171
# Layer 2 gradient norm: 0.26856714487075806
# Layer 3 gradient norm: 0.02202235907316208
# Layer 0 gradient norm: 0.3149818480014801
# Layer 1 gradient norm: 0.0365980789065361
# Layer 2 gradient norm: 0.26895415782928467
# Layer 3 gradient norm: 0.021995238959789276
#  691/1875 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.9878 - loss: 0.0414Layer 0 gradient norm: 0.3143058717250824
# Layer 1 gradient norm: 0.0365191325545311
# Layer 2 gradient norm: 0.2686323821544647
# Layer 3 gradient norm: 0.021914681419730186
# Layer 0 gradient norm: 0.31390640139579773
# Layer 1 gradient norm: 0.036457184702157974
# Layer 2 gradient norm: 0.26881203055381775
# Layer 3 gradient norm: 0.02189861796796322
#  693/1875 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.9878 - loss: 0.0414Layer 0 gradient norm: 0.3136409819126129
# Layer 1 gradient norm: 0.036435116082429886
# Layer 2 gradient norm: 0.2690364122390747
# Layer 3 gradient norm: 0.021883977577090263
# Layer 0 gradient norm: 0.3171652555465698
# Layer 1 gradient norm: 0.03686033934354782
# Layer 2 gradient norm: 0.27273815870285034
# Layer 3 gradient norm: 0.022141261026263237
# Layer 0 gradient norm: 0.31922364234924316
# Layer 1 gradient norm: 0.0371386893093586
# Layer 2 gradient norm: 0.2747691869735718
# Layer 3 gradient norm: 0.022232474759221077
#  696/1875 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.9878 - loss: 0.0414Layer 0 gradient norm: 0.32513195276260376
# Layer 1 gradient norm: 0.03784763813018799
# Layer 2 gradient norm: 0.2803436815738678
# Layer 3 gradient norm: 0.02263575606048107
# Layer 0 gradient norm: 0.3307035267353058
# Layer 1 gradient norm: 0.03850415349006653
# Layer 2 gradient norm: 0.2856840193271637
# Layer 3 gradient norm: 0.023023130372166634
# Layer 0 gradient norm: 0.3231038451194763
# Layer 1 gradient norm: 0.037618573755025864
# Layer 2 gradient norm: 0.2790811359882355
# Layer 3 gradient norm: 0.022457174956798553
#  699/1875 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.9878 - loss: 0.0414Layer 0 gradient norm: 0.31495967507362366
# Layer 1 gradient norm: 0.036695342510938644
# Layer 2 gradient norm: 0.27342623472213745
# Layer 3 gradient norm: 0.021971924230456352
# Layer 0 gradient norm: 0.30656975507736206
# Layer 1 gradient norm: 0.035761456936597824
# Layer 2 gradient norm: 0.2699761390686035
# Layer 3 gradient norm: 0.021659523248672485
# Layer 0 gradient norm: 0.3024728298187256
# Layer 1 gradient norm: 0.03528852388262749
# Layer 2 gradient norm: 0.26661282777786255
# Layer 3 gradient norm: 0.021357355639338493
#  702/1875 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.9878 - loss: 0.0414Layer 0 gradient norm: 0.30162206292152405
# Layer 1 gradient norm: 0.035202205181121826
# Layer 2 gradient norm: 0.2636394202709198
# Layer 3 gradient norm: 0.021097173914313316
# Layer 0 gradient norm: 0.29941028356552124
# Layer 1 gradient norm: 0.03496686369180679
# Layer 2 gradient norm: 0.26204901933670044
# Layer 3 gradient norm: 0.021011481061577797
# Layer 0 gradient norm: 0.2940010130405426
# Layer 1 gradient norm: 0.034378621727228165
# Layer 2 gradient norm: 0.2597948908805847
# Layer 3 gradient norm: 0.02085895463824272
#  705/1875 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.9878 - loss: 0.0414Layer 0 gradient norm: 0.2864644229412079
# Layer 1 gradient norm: 0.03355076536536217
# Layer 2 gradient norm: 0.2532016932964325
# Layer 3 gradient norm: 0.02036917395889759
# Layer 0 gradient norm: 0.2855232059955597
# Layer 1 gradient norm: 0.03351087123155594
# Layer 2 gradient norm: 0.25184446573257446
# Layer 3 gradient norm: 0.020360643044114113
#  707/1875 ━━━━━━━━━━━━━━━━━━━━ 26s 23ms/step - accuracy: 0.9878 - loss: 0.0414Layer 0 gradient norm: 0.2726399600505829
# Layer 1 gradient norm: 0.031921423971652985
# Layer 2 gradient norm: 0.24929702281951904
# Layer 3 gradient norm: 0.020236816257238388
# Layer 0 gradient norm: 0.270445853471756
# Layer 1 gradient norm: 0.03171554207801819
# Layer 2 gradient norm: 0.2464061975479126
# Layer 3 gradient norm: 0.020067065954208374
# Layer 0 gradient norm: 0.2692349851131439
# Layer 1 gradient norm: 0.031611379235982895
# Layer 2 gradient norm: 0.24508094787597656
# Layer 3 gradient norm: 0.01999744027853012
#  710/1875 ━━━━━━━━━━━━━━━━━━━━ 26s 23ms/step - accuracy: 0.9878 - loss: 0.0414Layer 0 gradient norm: 0.2680387496948242
# Layer 1 gradient norm: 0.0314960777759552
# Layer 2 gradient norm: 0.2437952160835266
# Layer 3 gradient norm: 0.019922452047467232
# Layer 0 gradient norm: 0.26740512251853943
# Layer 1 gradient norm: 0.03143532574176788
# Layer 2 gradient norm: 0.24268792569637299
# Layer 3 gradient norm: 0.019882425665855408
# Layer 0 gradient norm: 0.27820107340812683
# Layer 1 gradient norm: 0.03273749351501465
# Layer 2 gradient norm: 0.2518426477909088
# Layer 3 gradient norm: 0.02070874534547329
#  713/1875 ━━━━━━━━━━━━━━━━━━━━ 26s 23ms/step - accuracy: 0.9878 - loss: 0.0415Layer 0 gradient norm: 0.2887072265148163
# Layer 1 gradient norm: 0.03399838134646416
# Layer 2 gradient norm: 0.26084327697753906
# Layer 3 gradient norm: 0.021514583379030228
# Layer 0 gradient norm: 0.29346540570259094
# Layer 1 gradient norm: 0.034536298364400864
# Layer 2 gradient norm: 0.2683897018432617
# Layer 3 gradient norm: 0.02218686416745186
# Layer 0 gradient norm: 0.3006885051727295
# Layer 1 gradient norm: 0.0353994183242321
# Layer 2 gradient norm: 0.27488014101982117
# Layer 3 gradient norm: 0.022767744958400726
#  716/1875 ━━━━━━━━━━━━━━━━━━━━ 26s 23ms/step - accuracy: 0.9878 - loss: 0.0415Layer 0 gradient norm: 0.30650028586387634
# Layer 1 gradient norm: 0.036093227565288544
# Layer 2 gradient norm: 0.28013888001441956
# Layer 3 gradient norm: 0.02323579601943493
# Layer 0 gradient norm: 0.31112438440322876
# Layer 1 gradient norm: 0.03664569556713104
# Layer 2 gradient norm: 0.2843209207057953
# Layer 3 gradient norm: 0.02361089549958706
# Layer 0 gradient norm: 0.3151037395000458
# Layer 1 gradient norm: 0.03714947775006294
# Layer 2 gradient norm: 0.28785139322280884
# Layer 3 gradient norm: 0.023927293717861176
#  719/1875 ━━━━━━━━━━━━━━━━━━━━ 26s 23ms/step - accuracy: 0.9878 - loss: 0.0415Layer 0 gradient norm: 0.31873899698257446
# Layer 1 gradient norm: 0.037572406232357025
# Layer 2 gradient norm: 0.29012513160705566
# Layer 3 gradient norm: 0.024140510708093643
# Layer 0 gradient norm: 0.32094240188598633
# Layer 1 gradient norm: 0.03782093524932861
# Layer 2 gradient norm: 0.29202473163604736
# Layer 3 gradient norm: 0.024311786517500877
# Layer 0 gradient norm: 0.31965360045433044
# Layer 1 gradient norm: 0.03762815520167351
# Layer 2 gradient norm: 0.29087111353874207
# Layer 3 gradient norm: 0.024218972772359848
#  722/1875 ━━━━━━━━━━━━━━━━━━━━ 26s 23ms/step - accuracy: 0.9878 - loss: 0.0415Layer 0 gradient norm: 0.32538047432899475
# Layer 1 gradient norm: 0.03832722455263138
# Layer 2 gradient norm: 0.2960730195045471
# Layer 3 gradient norm: 0.024695107713341713
# Layer 0 gradient norm: 0.33148035407066345
# Layer 1 gradient norm: 0.039077021181583405
# Layer 2 gradient norm: 0.3016335070133209
# Layer 3 gradient norm: 0.025201424956321716
# Layer 0 gradient norm: 0.3357371389865875
# Layer 1 gradient norm: 0.039593420922756195
# Layer 2 gradient norm: 0.3052884340286255
# Layer 3 gradient norm: 0.025545231997966766
#  725/1875 ━━━━━━━━━━━━━━━━━━━━ 26s 23ms/step - accuracy: 0.9878 - loss: 0.0415Layer 0 gradient norm: 0.33941540122032166
# Layer 1 gradient norm: 0.040045950561761856
# Layer 2 gradient norm: 0.30844786763191223
# Layer 3 gradient norm: 0.025837190449237823
# Layer 0 gradient norm: 0.34146252274513245
# Layer 1 gradient norm: 0.04030168056488037
# Layer 2 gradient norm: 0.31016358733177185
# Layer 3 gradient norm: 0.02600095048546791
# Layer 0 gradient norm: 0.3422902822494507
# Layer 1 gradient norm: 0.04040917009115219
# Layer 2 gradient norm: 0.3105601966381073
# Layer 3 gradient norm: 0.026059474796056747
#  728/1875 ━━━━━━━━━━━━━━━━━━━━ 26s 23ms/step - accuracy: 0.9878 - loss: 0.0415Layer 0 gradient norm: 0.3427641689777374
# Layer 1 gradient norm: 0.04047327861189842
# Layer 2 gradient norm: 0.3107243776321411
# Layer 3 gradient norm: 0.026092369109392166
# Layer 0 gradient norm: 0.3415504992008209
# Layer 1 gradient norm: 0.0403398796916008
# Layer 2 gradient norm: 0.30898675322532654
# Layer 3 gradient norm: 0.02595205418765545
# Layer 0 gradient norm: 0.33894649147987366
# Layer 1 gradient norm: 0.04002897068858147
# Layer 2 gradient norm: 0.3063957393169403
# Layer 3 gradient norm: 0.025743970647454262
#  731/1875 ━━━━━━━━━━━━━━━━━━━━ 26s 23ms/step - accuracy: 0.9878 - loss: 0.0415Layer 0 gradient norm: 0.3366982638835907
# Layer 1 gradient norm: 0.03976104408502579
# Layer 2 gradient norm: 0.3040243983268738
# Layer 3 gradient norm: 0.02555709518492222
# Layer 0 gradient norm: 0.33476054668426514
# Layer 1 gradient norm: 0.03953464701771736
# Layer 2 gradient norm: 0.3019883632659912
# Layer 3 gradient norm: 0.02539614401757717
# Layer 0 gradient norm: 0.3328796923160553
# Layer 1 gradient norm: 0.039319027215242386
# Layer 2 gradient norm: 0.30022141337394714
# Layer 3 gradient norm: 0.025243893265724182
#  734/1875 ━━━━━━━━━━━━━━━━━━━━ 26s 23ms/step - accuracy: 0.9877 - loss: 0.0415Layer 0 gradient norm: 0.3265685737133026
# Layer 1 gradient norm: 0.038574498146772385
# Layer 2 gradient norm: 0.294361412525177
# Layer 3 gradient norm: 0.02475605718791485
# Layer 0 gradient norm: 0.3231753706932068
# Layer 1 gradient norm: 0.03816734999418259
# Layer 2 gradient norm: 0.28843897581100464
# Layer 3 gradient norm: 0.024260787293314934
# Layer 0 gradient norm: 0.3165333569049835
# Layer 1 gradient norm: 0.03738673776388168
# Layer 2 gradient norm: 0.2820996940135956
# Layer 3 gradient norm: 0.023737460374832153
#  737/1875 ━━━━━━━━━━━━━━━━━━━━ 26s 23ms/step - accuracy: 0.9877 - loss: 0.0415Layer 0 gradient norm: 0.3040500283241272
# Layer 1 gradient norm: 0.03591384366154671
# Layer 2 gradient norm: 0.27253833413124084
# Layer 3 gradient norm: 0.02293546311557293
# Layer 0 gradient norm: 0.2948648929595947
# Layer 1 gradient norm: 0.03481396287679672
# Layer 2 gradient norm: 0.2646898627281189
# Layer 3 gradient norm: 0.02227158471941948
#  739/1875 ━━━━━━━━━━━━━━━━━━━━ 26s 23ms/step - accuracy: 0.9877 - loss: 0.0416Layer 0 gradient norm: 0.2900344729423523
# Layer 1 gradient norm: 0.0342368483543396
# Layer 2 gradient norm: 0.26019716262817383
# Layer 3 gradient norm: 0.02189645916223526
# Layer 0 gradient norm: 0.28290459513664246
# Layer 1 gradient norm: 0.033387504518032074
# Layer 2 gradient norm: 0.2536298632621765
# Layer 3 gradient norm: 0.021354325115680695
#  741/1875 ━━━━━━━━━━━━━━━━━━━━ 26s 23ms/step - accuracy: 0.9877 - loss: 0.0416Layer 0 gradient norm: 0.2769160270690918
# Layer 1 gradient norm: 0.0326741561293602
# Layer 2 gradient norm: 0.24816733598709106
# Layer 3 gradient norm: 0.020900379866361618
# Layer 0 gradient norm: 0.2711695730686188
# Layer 1 gradient norm: 0.03198675811290741
# Layer 2 gradient norm: 0.24281448125839233
# Layer 3 gradient norm: 0.020459596067667007
# Layer 0 gradient norm: 0.26941806077957153
# Layer 1 gradient norm: 0.031774889677762985
# Layer 2 gradient norm: 0.24118956923484802
# Layer 3 gradient norm: 0.02032754011452198
#  744/1875 ━━━━━━━━━━━━━━━━━━━━ 26s 23ms/step - accuracy: 0.9877 - loss: 0.0416Layer 0 gradient norm: 0.26775577664375305
# Layer 1 gradient norm: 0.03157288581132889
# Layer 2 gradient norm: 0.23982222378253937
# Layer 3 gradient norm: 0.02020013891160488
# Layer 0 gradient norm: 0.2680581510066986
# Layer 1 gradient norm: 0.03158891946077347
# Layer 2 gradient norm: 0.23888754844665527
# Layer 3 gradient norm: 0.020107371732592583
# Layer 0 gradient norm: 0.26676446199417114
# Layer 1 gradient norm: 0.031422704458236694
# Layer 2 gradient norm: 0.23784130811691284
# Layer 3 gradient norm: 0.0200030654668808
#  747/1875 ━━━━━━━━━━━━━━━━━━━━ 26s 23ms/step - accuracy: 0.9877 - loss: 0.0416Layer 0 gradient norm: 0.2721133530139923
# Layer 1 gradient norm: 0.03205101191997528
# Layer 2 gradient norm: 0.24281713366508484
# Layer 3 gradient norm: 0.02041434869170189
# Layer 0 gradient norm: 0.27722373604774475
# Layer 1 gradient norm: 0.03265814855694771
# Layer 2 gradient norm: 0.2474604994058609
# Layer 3 gradient norm: 0.020808974280953407
#  749/1875 ━━━━━━━━━━━━━━━━━━━━ 26s 23ms/step - accuracy: 0.9877 - loss: 0.0416Layer 0 gradient norm: 0.2825350761413574
# Layer 1 gradient norm: 0.03329310566186905
# Layer 2 gradient norm: 0.2523103952407837
# Layer 3 gradient norm: 0.02122211642563343
# Layer 0 gradient norm: 0.28627002239227295
# Layer 1 gradient norm: 0.03374260663986206
# Layer 2 gradient norm: 0.2557058036327362
# Layer 3 gradient norm: 0.021512610837817192
# Layer 0 gradient norm: 0.2923344671726227
# Layer 1 gradient norm: 0.03447980806231499
# Layer 2 gradient norm: 0.2609310746192932
# Layer 3 gradient norm: 0.021982815116643906
#  752/1875 ━━━━━━━━━━━━━━━━━━━━ 25s 23ms/step - accuracy: 0.9877 - loss: 0.0416Layer 0 gradient norm: 0.2962866425514221
# Layer 1 gradient norm: 0.03497665748000145
# Layer 2 gradient norm: 0.26381969451904297
# Layer 3 gradient norm: 0.022295081987977028
# Layer 0 gradient norm: 0.3116692006587982
# Layer 1 gradient norm: 0.036772385239601135
# Layer 2 gradient norm: 0.26753634214401245
# Layer 3 gradient norm: 0.02267429232597351
# Layer 0 gradient norm: 0.31675127148628235
# Layer 1 gradient norm: 0.037407949566841125
# Layer 2 gradient norm: 0.27125248312950134
# Layer 3 gradient norm: 0.023056920617818832
#  755/1875 ━━━━━━━━━━━━━━━━━━━━ 25s 23ms/step - accuracy: 0.9877 - loss: 0.0416Layer 0 gradient norm: 0.32092124223709106
# Layer 1 gradient norm: 0.03793024271726608
# Layer 2 gradient norm: 0.27424612641334534
# Layer 3 gradient norm: 0.023371268063783646
# Layer 0 gradient norm: 0.32329273223876953
# Layer 1 gradient norm: 0.03823862597346306
# Layer 2 gradient norm: 0.2757957875728607
# Layer 3 gradient norm: 0.023554272949695587
# Layer 0 gradient norm: 0.3197375237941742
# Layer 1 gradient norm: 0.037857551127672195
# Layer 2 gradient norm: 0.27185875177383423
# Layer 3 gradient norm: 0.023301517590880394
#  758/1875 ━━━━━━━━━━━━━━━━━━━━ 25s 23ms/step - accuracy: 0.9877 - loss: 0.0416Layer 0 gradient norm: 0.31834661960601807
# Layer 1 gradient norm: 0.037725839763879776
# Layer 2 gradient norm: 0.2697778344154358
# Layer 3 gradient norm: 0.023198900744318962
# Layer 0 gradient norm: 0.31748586893081665
# Layer 1 gradient norm: 0.03764835745096207
# Layer 2 gradient norm: 0.2682507634162903
# Layer 3 gradient norm: 0.023135539144277573
# Layer 0 gradient norm: 0.3146701455116272
# Layer 1 gradient norm: 0.03733677417039871
# Layer 2 gradient norm: 0.26514118909835815
# Layer 3 gradient norm: 0.022927332669496536
#  761/1875 ━━━━━━━━━━━━━━━━━━━━ 25s 23ms/step - accuracy: 0.9877 - loss: 0.0416Layer 0 gradient norm: 0.31382742524147034
# Layer 1 gradient norm: 0.03725402429699898
# Layer 2 gradient norm: 0.2638402283191681
# Layer 3 gradient norm: 0.02286478318274021
# Layer 0 gradient norm: 0.31290683150291443
# Layer 1 gradient norm: 0.037160877138376236
# Layer 2 gradient norm: 0.2625407576560974
# Layer 3 gradient norm: 0.02279535122215748
# Layer 0 gradient norm: 0.2867852449417114
# Layer 1 gradient norm: 0.0340767465531826
# Layer 2 gradient norm: 0.24097950756549835
# Layer 3 gradient norm: 0.020981458947062492
#  764/1875 ━━━━━━━━━━━━━━━━━━━━ 25s 23ms/step - accuracy: 0.9877 - loss: 0.0416Layer 0 gradient norm: 0.26518023014068604
# Layer 1 gradient norm: 0.031509995460510254
# Layer 2 gradient norm: 0.2221156507730484
# Layer 3 gradient norm: 0.019383948296308517
# Layer 0 gradient norm: 0.24608752131462097
# Layer 1 gradient norm: 0.029241418465971947
# Layer 2 gradient norm: 0.20551936328411102
# Layer 3 gradient norm: 0.017971206456422806
# Layer 0 gradient norm: 0.2261606901884079
# Layer 1 gradient norm: 0.026853464543819427
# Layer 2 gradient norm: 0.1884843111038208
# Layer 3 gradient norm: 0.0165005624294281
#  767/1875 ━━━━━━━━━━━━━━━━━━━━ 25s 23ms/step - accuracy: 0.9877 - loss: 0.0416Layer 0 gradient norm: 0.2148783802986145
# Layer 1 gradient norm: 0.025561578571796417
# Layer 2 gradient norm: 0.17271432280540466
# Layer 3 gradient norm: 0.015128036960959435
# Layer 0 gradient norm: 0.20049580931663513
# Layer 1 gradient norm: 0.023847786709666252
# Layer 2 gradient norm: 0.16099639236927032
# Layer 3 gradient norm: 0.01410471461713314
# Layer 0 gradient norm: 0.18669450283050537
# Layer 1 gradient norm: 0.022199444472789764
# Layer 2 gradient norm: 0.14980000257492065
# Layer 3 gradient norm: 0.013119504787027836
#  770/1875 ━━━━━━━━━━━━━━━━━━━━ 25s 23ms/step - accuracy: 0.9877 - loss: 0.0417Layer 0 gradient norm: 0.17739880084991455
# Layer 1 gradient norm: 0.021116122603416443
# Layer 2 gradient norm: 0.1423271894454956
# Layer 3 gradient norm: 0.012464048340916634
# Layer 0 gradient norm: 0.16658946871757507
# Layer 1 gradient norm: 0.019787905737757683
# Layer 2 gradient norm: 0.13975347578525543
# Layer 3 gradient norm: 0.01223719958215952
# Layer 0 gradient norm: 0.16263262927532196
# Layer 1 gradient norm: 0.019322777166962624
# Layer 2 gradient norm: 0.13660964369773865
# Layer 3 gradient norm: 0.011959128081798553
#  773/1875 ━━━━━━━━━━━━━━━━━━━━ 25s 23ms/step - accuracy: 0.9877 - loss: 0.0417Layer 0 gradient norm: 0.15623682737350464
# Layer 1 gradient norm: 0.01857224479317665
# Layer 2 gradient norm: 0.1314726173877716
# Layer 3 gradient norm: 0.011499851010739803
# Layer 0 gradient norm: 0.14785750210285187
# Layer 1 gradient norm: 0.017572658136487007
# Layer 2 gradient norm: 0.12477117031812668
# Layer 3 gradient norm: 0.010889525525271893
# Layer 0 gradient norm: 0.14069950580596924
# Layer 1 gradient norm: 0.016728276386857033
# Layer 2 gradient norm: 0.11897122114896774
# Layer 3 gradient norm: 0.010369107127189636
#  776/1875 ━━━━━━━━━━━━━━━━━━━━ 25s 23ms/step - accuracy: 0.9877 - loss: 0.0417Layer 0 gradient norm: 0.14506947994232178
# Layer 1 gradient norm: 0.017255231738090515
# Layer 2 gradient norm: 0.12170025706291199
# Layer 3 gradient norm: 0.010610693134367466
# Layer 0 gradient norm: 0.14835502207279205
# Layer 1 gradient norm: 0.01764749363064766
# Layer 2 gradient norm: 0.12458792328834534
# Layer 3 gradient norm: 0.010865611024200916
# Layer 0 gradient norm: 0.15238024294376373
# Layer 1 gradient norm: 0.018105313181877136
# Layer 2 gradient norm: 0.1272636502981186
# Layer 3 gradient norm: 0.011096294037997723
#  779/1875 ━━━━━━━━━━━━━━━━━━━━ 25s 23ms/step - accuracy: 0.9877 - loss: 0.0417Layer 0 gradient norm: 0.15285976231098175
# Layer 1 gradient norm: 0.018074996769428253
# Layer 2 gradient norm: 0.12593890726566315
# Layer 3 gradient norm: 0.010961946099996567
# Layer 0 gradient norm: 0.15070928633213043
# Layer 1 gradient norm: 0.01781044527888298
# Layer 2 gradient norm: 0.12414560467004776
# Layer 3 gradient norm: 0.010785957798361778
# Layer 0 gradient norm: 0.15010389685630798
# Layer 1 gradient norm: 0.017713308334350586
# Layer 2 gradient norm: 0.12287964671850204
# Layer 3 gradient norm: 0.010654688812792301
#  782/1875 ━━━━━━━━━━━━━━━━━━━━ 25s 23ms/step - accuracy: 0.9877 - loss: 0.0417Layer 0 gradient norm: 0.1454315185546875
# Layer 1 gradient norm: 0.01717737689614296
# Layer 2 gradient norm: 0.12234802544116974
# Layer 3 gradient norm: 0.010588133707642555
# Layer 0 gradient norm: 0.14555099606513977
# Layer 1 gradient norm: 0.017185861244797707
# Layer 2 gradient norm: 0.12234200537204742
# Layer 3 gradient norm: 0.01056730281561613
# Layer 0 gradient norm: 0.14521168172359467
# Layer 1 gradient norm: 0.017141029238700867
# Layer 2 gradient norm: 0.12197951227426529
# Layer 3 gradient norm: 0.010515016503632069
#  785/1875 ━━━━━━━━━━━━━━━━━━━━ 25s 23ms/step - accuracy: 0.9877 - loss: 0.0417Layer 0 gradient norm: 0.1473429948091507
# Layer 1 gradient norm: 0.017392100766301155
# Layer 2 gradient norm: 0.12390613555908203
# Layer 3 gradient norm: 0.01066199317574501
# Layer 0 gradient norm: 0.14991387724876404
# Layer 1 gradient norm: 0.01769566349685192
# Layer 2 gradient norm: 0.12627100944519043
# Layer 3 gradient norm: 0.010847168043255806
#  787/1875 ━━━━━━━━━━━━━━━━━━━━ 25s 23ms/step - accuracy: 0.9877 - loss: 0.0417Layer 0 gradient norm: 0.16389864683151245
# Layer 1 gradient norm: 0.019332464784383774
# Layer 2 gradient norm: 0.13502144813537598
# Layer 3 gradient norm: 0.0116073964163661
# Layer 0 gradient norm: 0.1820281445980072
# Layer 1 gradient norm: 0.021518301218748093
# Layer 2 gradient norm: 0.15029975771903992
# Layer 3 gradient norm: 0.012944751419126987
# Layer 0 gradient norm: 0.19845043122768402
# Layer 1 gradient norm: 0.02348664589226246
# Layer 2 gradient norm: 0.1641547828912735
# Layer 3 gradient norm: 0.01414855383336544
#  790/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 23ms/step - accuracy: 0.9877 - loss: 0.0417Layer 0 gradient norm: 0.2146856188774109
# Layer 1 gradient norm: 0.02543172426521778
# Layer 2 gradient norm: 0.17795471847057343
# Layer 3 gradient norm: 0.015339988283813
# Layer 0 gradient norm: 0.23509091138839722
# Layer 1 gradient norm: 0.027852922677993774
# Layer 2 gradient norm: 0.19521744549274445
# Layer 3 gradient norm: 0.01681346446275711
# Layer 0 gradient norm: 0.25395289063453674
# Layer 1 gradient norm: 0.030095674097537994
# Layer 2 gradient norm: 0.21121905744075775
# Layer 3 gradient norm: 0.018165525048971176
#  793/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 23ms/step - accuracy: 0.9877 - loss: 0.0417Layer 0 gradient norm: 0.2708367109298706
# Layer 1 gradient norm: 0.03209342807531357
# Layer 2 gradient norm: 0.22618214786052704
# Layer 3 gradient norm: 0.019428547471761703
# Layer 0 gradient norm: 0.28736352920532227
# Layer 1 gradient norm: 0.034051984548568726
# Layer 2 gradient norm: 0.24058696627616882
# Layer 3 gradient norm: 0.020668204873800278
# Layer 0 gradient norm: 0.3042455315589905
# Layer 1 gradient norm: 0.03605520352721214
# Layer 2 gradient norm: 0.2552845776081085
# Layer 3 gradient norm: 0.021927792578935623
#  796/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 23ms/step - accuracy: 0.9877 - loss: 0.0417Layer 0 gradient norm: 0.318372517824173
# Layer 1 gradient norm: 0.03773102909326553
# Layer 2 gradient norm: 0.2668834924697876
# Layer 3 gradient norm: 0.022926997393369675
# Layer 0 gradient norm: 0.3279632031917572
# Layer 1 gradient norm: 0.038862988352775574
# Layer 2 gradient norm: 0.2748461961746216
# Layer 3 gradient norm: 0.023596158251166344
# Layer 0 gradient norm: 0.3334208130836487
# Layer 1 gradient norm: 0.03950628265738487
# Layer 2 gradient norm: 0.27947965264320374
# Layer 3 gradient norm: 0.02397136017680168
#  799/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 23ms/step - accuracy: 0.9877 - loss: 0.0417Layer 0 gradient norm: 0.3387303054332733
# Layer 1 gradient norm: 0.0401059165596962
# Layer 2 gradient norm: 0.2842442989349365
# Layer 3 gradient norm: 0.024351470172405243
# Layer 0 gradient norm: 0.3468204736709595
# Layer 1 gradient norm: 0.041063226759433746
# Layer 2 gradient norm: 0.2926604747772217
# Layer 3 gradient norm: 0.02499965950846672
# Layer 0 gradient norm: 0.3543326258659363
# Layer 1 gradient norm: 0.04194880649447441
# Layer 2 gradient norm: 0.2999904155731201
# Layer 3 gradient norm: 0.025558866560459137
#  802/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 23ms/step - accuracy: 0.9876 - loss: 0.0418Layer 0 gradient norm: 0.3617207109928131
# Layer 1 gradient norm: 0.04283389821648598
# Layer 2 gradient norm: 0.30713126063346863
# Layer 3 gradient norm: 0.026103002950549126
# Layer 0 gradient norm: 0.3671838939189911
# Layer 1 gradient norm: 0.043458856642246246
# Layer 2 gradient norm: 0.31351789832115173
# Layer 3 gradient norm: 0.026575500145554543
# Layer 0 gradient norm: 0.37007707357406616
# Layer 1 gradient norm: 0.04378142207860947
# Layer 2 gradient norm: 0.3165864646434784
# Layer 3 gradient norm: 0.026762112975120544
#  805/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 23ms/step - accuracy: 0.9876 - loss: 0.0418Layer 0 gradient norm: 0.3721957206726074
# Layer 1 gradient norm: 0.04402122646570206
# Layer 2 gradient norm: 0.3189033567905426
# Layer 3 gradient norm: 0.026884665712714195
# Layer 0 gradient norm: 0.3785336911678314
# Layer 1 gradient norm: 0.0447656586766243
# Layer 2 gradient norm: 0.32558321952819824
# Layer 3 gradient norm: 0.027361812070012093
# Layer 0 gradient norm: 0.37636226415634155
# Layer 1 gradient norm: 0.044463735073804855
# Layer 2 gradient norm: 0.3245196044445038
# Layer 3 gradient norm: 0.027169104665517807
#  808/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 23ms/step - accuracy: 0.9876 - loss: 0.0418Layer 0 gradient norm: 0.38418522477149963
# Layer 1 gradient norm: 0.045423828065395355
# Layer 2 gradient norm: 0.32287484407424927
# Layer 3 gradient norm: 0.026934294030070305
# Layer 0 gradient norm: 0.37108322978019714
# Layer 1 gradient norm: 0.043826669454574585
# Layer 2 gradient norm: 0.3123261332511902
# Layer 3 gradient norm: 0.025962308049201965
# Layer 0 gradient norm: 0.3563346266746521
# Layer 1 gradient norm: 0.04204738512635231
# Layer 2 gradient norm: 0.30182063579559326
# Layer 3 gradient norm: 0.0250008013099432
#  811/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 23ms/step - accuracy: 0.9876 - loss: 0.0418Layer 0 gradient norm: 0.34555551409721375
# Layer 1 gradient norm: 0.04074442386627197
# Layer 2 gradient norm: 0.292497456073761
# Layer 3 gradient norm: 0.024151179939508438
# Layer 0 gradient norm: 0.34284788370132446
# Layer 1 gradient norm: 0.04043280705809593
# Layer 2 gradient norm: 0.29013773798942566
# Layer 3 gradient norm: 0.02396159991621971
# Layer 0 gradient norm: 0.34522294998168945
# Layer 1 gradient norm: 0.04073331877589226
# Layer 2 gradient norm: 0.29207271337509155
# Layer 3 gradient norm: 0.02413799613714218
#  814/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 23ms/step - accuracy: 0.9876 - loss: 0.0418Layer 0 gradient norm: 0.3489306569099426
# Layer 1 gradient norm: 0.04118882119655609
# Layer 2 gradient norm: 0.2951754927635193
# Layer 3 gradient norm: 0.024405691772699356
# Layer 0 gradient norm: 0.3457960784435272
# Layer 1 gradient norm: 0.04081856831908226
# Layer 2 gradient norm: 0.294916570186615
# Layer 3 gradient norm: 0.024380039423704147
# Layer 0 gradient norm: 0.3475647270679474
# Layer 1 gradient norm: 0.0410483255982399
# Layer 2 gradient norm: 0.29651185870170593
# Layer 3 gradient norm: 0.024534350261092186
#  817/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 23ms/step - accuracy: 0.9876 - loss: 0.0418Layer 0 gradient norm: 0.3502945005893707
# Layer 1 gradient norm: 0.041389383375644684
# Layer 2 gradient norm: 0.2988024353981018
# Layer 3 gradient norm: 0.024749327450990677
# Layer 0 gradient norm: 0.3512062132358551
# Layer 1 gradient norm: 0.04150795191526413
# Layer 2 gradient norm: 0.2991008758544922
# Layer 3 gradient norm: 0.02479611709713936
# Layer 0 gradient norm: 0.35370954871177673
# Layer 1 gradient norm: 0.04180912300944328
# Layer 2 gradient norm: 0.300794392824173
# Layer 3 gradient norm: 0.024959173053503036
#  820/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 23ms/step - accuracy: 0.9876 - loss: 0.0418Layer 0 gradient norm: 0.3537302613258362
# Layer 1 gradient norm: 0.041824694722890854
# Layer 2 gradient norm: 0.2996874153614044
# Layer 3 gradient norm: 0.02489590272307396
# Layer 0 gradient norm: 0.3520410656929016
# Layer 1 gradient norm: 0.0416368693113327
# Layer 2 gradient norm: 0.29797881841659546
# Layer 3 gradient norm: 0.024777783080935478
# Layer 0 gradient norm: 0.36091578006744385
# Layer 1 gradient norm: 0.04271378740668297
# Layer 2 gradient norm: 0.3052006661891937
# Layer 3 gradient norm: 0.025404658168554306
#  823/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 23ms/step - accuracy: 0.9876 - loss: 0.0418Layer 0 gradient norm: 0.36800771951675415
# Layer 1 gradient norm: 0.043573006987571716
# Layer 2 gradient norm: 0.3107423782348633
# Layer 3 gradient norm: 0.025897255167365074
# Layer 0 gradient norm: 0.3756774663925171
# Layer 1 gradient norm: 0.04449662193655968
# Layer 2 gradient norm: 0.31673532724380493
# Layer 3 gradient norm: 0.02643156610429287
# Layer 0 gradient norm: 0.3785048723220825
# Layer 1 gradient norm: 0.04482661560177803
# Layer 2 gradient norm: 0.31786850094795227
# Layer 3 gradient norm: 0.02654496766626835
#  826/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 23ms/step - accuracy: 0.9876 - loss: 0.0418Layer 0 gradient norm: 0.3867745101451874
# Layer 1 gradient norm: 0.04580773785710335
# Layer 2 gradient norm: 0.32405149936676025
# Layer 3 gradient norm: 0.02707165665924549
# Layer 0 gradient norm: 0.39433276653289795
# Layer 1 gradient norm: 0.046703990548849106
# Layer 2 gradient norm: 0.3298133313655853
# Layer 3 gradient norm: 0.027559537440538406
# Layer 0 gradient norm: 0.39707356691360474
# Layer 1 gradient norm: 0.04704614356160164
# Layer 2 gradient norm: 0.333059161901474
# Layer 3 gradient norm: 0.0278342105448246
#  829/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 23ms/step - accuracy: 0.9876 - loss: 0.0418Layer 0 gradient norm: 0.4019419848918915
# Layer 1 gradient norm: 0.047629307955503464
# Layer 2 gradient norm: 0.336311936378479
# Layer 3 gradient norm: 0.02809629589319229
# Layer 0 gradient norm: 0.40703704953193665
# Layer 1 gradient norm: 0.048260144889354706
# Layer 2 gradient norm: 0.34038060903549194
# Layer 3 gradient norm: 0.028426341712474823
# Layer 0 gradient norm: 0.4037526845932007
# Layer 1 gradient norm: 0.04787838086485863
# Layer 2 gradient norm: 0.3374330997467041
# Layer 3 gradient norm: 0.0281730554997921
#  832/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 23ms/step - accuracy: 0.9876 - loss: 0.0418Layer 0 gradient norm: 0.4030560851097107
# Layer 1 gradient norm: 0.04776201397180557
# Layer 2 gradient norm: 0.336195170879364
# Layer 3 gradient norm: 0.02810581773519516
# Layer 0 gradient norm: 0.40409624576568604
# Layer 1 gradient norm: 0.0478869304060936
# Layer 2 gradient norm: 0.3367163836956024
# Layer 3 gradient norm: 0.02817530743777752
# Layer 0 gradient norm: 0.3967750668525696
# Layer 1 gradient norm: 0.04704957827925682
# Layer 2 gradient norm: 0.332684725522995
# Layer 3 gradient norm: 0.027869751676917076
#  835/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 23ms/step - accuracy: 0.9876 - loss: 0.0419Layer 0 gradient norm: 0.39415502548217773
# Layer 1 gradient norm: 0.046737153083086014
# Layer 2 gradient norm: 0.33011794090270996
# Layer 3 gradient norm: 0.027676496654748917
# Layer 0 gradient norm: 0.37378349900245667
# Layer 1 gradient norm: 0.04429762437939644
# Layer 2 gradient norm: 0.31453800201416016
# Layer 3 gradient norm: 0.02630622498691082
#  837/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 23ms/step - accuracy: 0.9876 - loss: 0.0419Layer 0 gradient norm: 0.34941911697387695
# Layer 1 gradient norm: 0.04137788712978363
# Layer 2 gradient norm: 0.294565886259079
# Layer 3 gradient norm: 0.024551525712013245
# Layer 0 gradient norm: 0.3267703354358673
# Layer 1 gradient norm: 0.038659993559122086
# Layer 2 gradient norm: 0.2760466933250427
# Layer 3 gradient norm: 0.022939810529351234
# Layer 0 gradient norm: 0.30510106682777405
# Layer 1 gradient norm: 0.03607530891895294
# Layer 2 gradient norm: 0.2591620087623596
# Layer 3 gradient norm: 0.021470941603183746
#  840/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 23ms/step - accuracy: 0.9876 - loss: 0.0419Layer 0 gradient norm: 0.28659236431121826
# Layer 1 gradient norm: 0.03384578227996826
# Layer 2 gradient norm: 0.24384048581123352
# Layer 3 gradient norm: 0.02013292722404003
# Layer 0 gradient norm: 0.270842969417572
# Layer 1 gradient norm: 0.03194761648774147
# Layer 2 gradient norm: 0.23079423606395721
# Layer 3 gradient norm: 0.018991617485880852
#  842/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 23ms/step - accuracy: 0.9876 - loss: 0.0419Layer 0 gradient norm: 0.25742006301879883
# Layer 1 gradient norm: 0.030384523794054985
# Layer 2 gradient norm: 0.21944692730903625
# Layer 3 gradient norm: 0.01800359971821308
# Layer 0 gradient norm: 0.24496442079544067
# Layer 1 gradient norm: 0.028879795223474503
# Layer 2 gradient norm: 0.20902591943740845
# Layer 3 gradient norm: 0.01709613762795925
#  844/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 23ms/step - accuracy: 0.9876 - loss: 0.0419Layer 0 gradient norm: 0.2319064438343048
# Layer 1 gradient norm: 0.02729010581970215
# Layer 2 gradient norm: 0.1981273591518402
# Layer 3 gradient norm: 0.01614202745258808
# Layer 0 gradient norm: 0.22001275420188904
# Layer 1 gradient norm: 0.02585180662572384
# Layer 2 gradient norm: 0.1880698949098587
# Layer 3 gradient norm: 0.015259782783687115
# Layer 0 gradient norm: 0.2080092579126358
# Layer 1 gradient norm: 0.024396495893597603
# Layer 2 gradient norm: 0.17764899134635925
# Layer 3 gradient norm: 0.014372341334819794
#  847/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 23ms/step - accuracy: 0.9876 - loss: 0.0419Layer 0 gradient norm: 0.1942148208618164
# Layer 1 gradient norm: 0.02271946333348751
# Layer 2 gradient norm: 0.16579149663448334
# Layer 3 gradient norm: 0.013361245393753052
# Layer 0 gradient norm: 0.180881530046463
# Layer 1 gradient norm: 0.02107996679842472
# Layer 2 gradient norm: 0.15444952249526978
# Layer 3 gradient norm: 0.012412382289767265
# Layer 0 gradient norm: 0.17049181461334229
# Layer 1 gradient norm: 0.01982549950480461
# Layer 2 gradient norm: 0.1453322172164917
# Layer 3 gradient norm: 0.011647817678749561
#  850/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 23ms/step - accuracy: 0.9876 - loss: 0.0419Layer 0 gradient norm: 0.1620595008134842
# Layer 1 gradient norm: 0.01878826506435871
# Layer 2 gradient norm: 0.13808682560920715
# Layer 3 gradient norm: 0.011035338044166565
# Layer 0 gradient norm: 0.1571541726589203
# Layer 1 gradient norm: 0.018203482031822205
# Layer 2 gradient norm: 0.1335572451353073
# Layer 3 gradient norm: 0.010644802823662758
# Layer 0 gradient norm: 0.15237747132778168
# Layer 1 gradient norm: 0.0176081582903862
# Layer 2 gradient norm: 0.12958167493343353
# Layer 3 gradient norm: 0.010290241800248623
#  853/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 23ms/step - accuracy: 0.9876 - loss: 0.0419Layer 0 gradient norm: 0.15044602751731873
# Layer 1 gradient norm: 0.017351286485791206
# Layer 2 gradient norm: 0.12685538828372955
# Layer 3 gradient norm: 0.010044198483228683
# Layer 0 gradient norm: 0.14979858696460724
# Layer 1 gradient norm: 0.017242111265659332
# Layer 2 gradient norm: 0.12644028663635254
# Layer 3 gradient norm: 0.00999840721487999
# Layer 0 gradient norm: 0.15044119954109192
# Layer 1 gradient norm: 0.017303824424743652
# Layer 2 gradient norm: 0.12705108523368835
# Layer 3 gradient norm: 0.010036572813987732
#  856/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 23ms/step - accuracy: 0.9876 - loss: 0.0419Layer 0 gradient norm: 0.15473730862140656
# Layer 1 gradient norm: 0.01781502738595009
# Layer 2 gradient norm: 0.13036978244781494
# Layer 3 gradient norm: 0.010276840068399906
# Layer 0 gradient norm: 0.15788495540618896
# Layer 1 gradient norm: 0.01819712482392788
# Layer 2 gradient norm: 0.1332663744688034
# Layer 3 gradient norm: 0.010482469573616982
# Layer 0 gradient norm: 0.16318614780902863
# Layer 1 gradient norm: 0.018878567963838577
# Layer 2 gradient norm: 0.13899043202400208
# Layer 3 gradient norm: 0.010934055782854557
#  859/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 23ms/step - accuracy: 0.9876 - loss: 0.0419Layer 0 gradient norm: 0.17069804668426514
# Layer 1 gradient norm: 0.0197701845318079
# Layer 2 gradient norm: 0.14574289321899414
# Layer 3 gradient norm: 0.011484404094517231
# Layer 0 gradient norm: 0.17772915959358215
# Layer 1 gradient norm: 0.020603785291314125
# Layer 2 gradient norm: 0.15209992229938507
# Layer 3 gradient norm: 0.011999400332570076
# Layer 0 gradient norm: 0.19499126076698303
# Layer 1 gradient norm: 0.022620711475610733
# Layer 2 gradient norm: 0.16650652885437012
# Layer 3 gradient norm: 0.01320210937410593
#  862/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 23ms/step - accuracy: 0.9876 - loss: 0.0419Layer 0 gradient norm: 0.21028001606464386
# Layer 1 gradient norm: 0.02445323020219803
# Layer 2 gradient norm: 0.18007595837116241
# Layer 3 gradient norm: 0.014328697696328163
# Layer 0 gradient norm: 0.22467392683029175
# Layer 1 gradient norm: 0.026181725785136223
# Layer 2 gradient norm: 0.1928359717130661
# Layer 3 gradient norm: 0.015385499224066734
# Layer 0 gradient norm: 0.24160853028297424
# Layer 1 gradient norm: 0.028241867199540138
# Layer 2 gradient norm: 0.2074577361345291
# Layer 3 gradient norm: 0.016652608290314674
#  865/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 23ms/step - accuracy: 0.9876 - loss: 0.0419Layer 0 gradient norm: 0.25801053643226624
# Layer 1 gradient norm: 0.030208924785256386
# Layer 2 gradient norm: 0.22149164974689484
# ...
# Layer 1 gradient norm: 0.007233256474137306
# Layer 2 gradient norm: 0.05390021577477455
# Layer 3 gradient norm: 0.0038760604802519083
# Layer 0 gradient norm: 0.06992150098085403
# Layer 1 gradient norm: 0.00823727436363697
# Layer 2 gradient norm: 0.06117339804768562
# Layer 3 gradient norm: 0.00449447613209486
# Layer 0 gradient norm: 0.07679003477096558
# Layer 1 gradient norm: 0.00917670875787735
# Layer 2 gradient norm: 0.06839807331562042
# Layer 3 gradient norm: 0.0050787474028766155
# 1799/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9868 - loss: 0.0431Layer 0 gradient norm: 0.08434567600488663
# Layer 1 gradient norm: 0.010124419815838337
# Layer 2 gradient norm: 0.076813243329525
# Layer 3 gradient norm: 0.005696495063602924
# Layer 0 gradient norm: 0.0927729681134224
# Layer 1 gradient norm: 0.011126765049993992
# Layer 2 gradient norm: 0.08662473410367966
# Layer 3 gradient norm: 0.006350768264383078
# Layer 0 gradient norm: 0.099553182721138
# Layer 1 gradient norm: 0.011755593121051788
# Layer 2 gradient norm: 0.09611871838569641
# Layer 3 gradient norm: 0.006882563699036837
# 1802/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9868 - loss: 0.0431Layer 0 gradient norm: 0.11226384341716766
# Layer 1 gradient norm: 0.013135917484760284
# Layer 2 gradient norm: 0.10913432389497757
# Layer 3 gradient norm: 0.007624667603522539
# Layer 0 gradient norm: 0.12399039417505264
# Layer 1 gradient norm: 0.014326328411698341
# Layer 2 gradient norm: 0.12433227896690369
# Layer 3 gradient norm: 0.008475170470774174
# Layer 0 gradient norm: 0.13752460479736328
# Layer 1 gradient norm: 0.015698952600359917
# Layer 2 gradient norm: 0.14170168340206146
# Layer 3 gradient norm: 0.009443087503314018
# 1805/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9868 - loss: 0.0431Layer 0 gradient norm: 0.15165461599826813
# Layer 1 gradient norm: 0.017160413786768913
# Layer 2 gradient norm: 0.1592688113451004
# Layer 3 gradient norm: 0.010375404730439186
# Layer 0 gradient norm: 0.1700616180896759
# Layer 1 gradient norm: 0.019105441868305206
# Layer 2 gradient norm: 0.18176932632923126
# Layer 3 gradient norm: 0.011699017137289047
# Layer 0 gradient norm: 0.1897861510515213
# Layer 1 gradient norm: 0.021261349320411682
# Layer 2 gradient norm: 0.2044847160577774
# Layer 3 gradient norm: 0.013006280176341534
# 1808/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9868 - loss: 0.0431Layer 0 gradient norm: 0.2083490937948227
# Layer 1 gradient norm: 0.023217804729938507
# Layer 2 gradient norm: 0.22673113644123077
# Layer 3 gradient norm: 0.014279669150710106
# Layer 0 gradient norm: 0.22653800249099731
# Layer 1 gradient norm: 0.025141900405287743
# Layer 2 gradient norm: 0.2485492080450058
# Layer 3 gradient norm: 0.015547988936305046
# Layer 0 gradient norm: 0.24696333706378937
# Layer 1 gradient norm: 0.027296803891658783
# Layer 2 gradient norm: 0.2729376554489136
# Layer 3 gradient norm: 0.016957426443696022
# 1811/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9868 - loss: 0.0431Layer 0 gradient norm: 0.241962730884552
# Layer 1 gradient norm: 0.02680632285773754
# Layer 2 gradient norm: 0.267350435256958
# Layer 3 gradient norm: 0.01679663546383381
# Layer 0 gradient norm: 0.2411118596792221
# Layer 1 gradient norm: 0.026763081550598145
# Layer 2 gradient norm: 0.2662965655326843
# Layer 3 gradient norm: 0.016892872750759125
# 1813/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9868 - loss: 0.0431Layer 0 gradient norm: 0.26300621032714844
# Layer 1 gradient norm: 0.029107803478837013
# Layer 2 gradient norm: 0.29217013716697693
# Layer 3 gradient norm: 0.018467141315340996
# Layer 0 gradient norm: 0.28154128789901733
# Layer 1 gradient norm: 0.031071756035089493
# Layer 2 gradient norm: 0.31602904200553894
# Layer 3 gradient norm: 0.019915105774998665
# 1815/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9868 - loss: 0.0431Layer 0 gradient norm: 0.2989359200000763
# Layer 1 gradient norm: 0.03292525187134743
# Layer 2 gradient norm: 0.33786219358444214
# Layer 3 gradient norm: 0.02123856544494629
# Layer 0 gradient norm: 0.31913164258003235
# Layer 1 gradient norm: 0.03509156033396721
# Layer 2 gradient norm: 0.36176905035972595
# Layer 3 gradient norm: 0.0226590596139431
# 1817/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9868 - loss: 0.0431Layer 0 gradient norm: 0.35280540585517883
# Layer 1 gradient norm: 0.03852544352412224
# Layer 2 gradient norm: 0.40974947810173035
# Layer 3 gradient norm: 0.025719376280903816
# Layer 0 gradient norm: 0.38513198494911194
# Layer 1 gradient norm: 0.04206894338130951
# Layer 2 gradient norm: 0.44944554567337036
# Layer 3 gradient norm: 0.028200438246130943
# 1819/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9868 - loss: 0.0431Layer 0 gradient norm: 0.41723689436912537
# Layer 1 gradient norm: 0.04558178409934044
# Layer 2 gradient norm: 0.48839271068573
# Layer 3 gradient norm: 0.030556993559002876
# Layer 0 gradient norm: 0.4490841329097748
# Layer 1 gradient norm: 0.04879782348871231
# Layer 2 gradient norm: 0.5185499787330627
# Layer 3 gradient norm: 0.032408688217401505
# 1821/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9868 - loss: 0.0432Layer 0 gradient norm: 0.47219452261924744
# Layer 1 gradient norm: 0.05137844383716583
# Layer 2 gradient norm: 0.5455061793327332
# Layer 3 gradient norm: 0.034159209579229355
# Layer 0 gradient norm: 0.48424071073532104
# Layer 1 gradient norm: 0.0528002493083477
# Layer 2 gradient norm: 0.558224081993103
# Layer 3 gradient norm: 0.03514871001243591
# 1823/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9868 - loss: 0.0432Layer 0 gradient norm: 0.48980775475502014
# Layer 1 gradient norm: 0.053547363728284836
# Layer 2 gradient norm: 0.5679548382759094
# Layer 3 gradient norm: 0.03598932921886444
# Layer 0 gradient norm: 0.49772077798843384
# Layer 1 gradient norm: 0.054522134363651276
# Layer 2 gradient norm: 0.5757895708084106
# Layer 3 gradient norm: 0.03669710084795952
# Layer 0 gradient norm: 0.5387668013572693
# Layer 1 gradient norm: 0.05930580943822861
# Layer 2 gradient norm: 0.57220458984375
# Layer 3 gradient norm: 0.03668658807873726
# 1826/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9868 - loss: 0.0432Layer 0 gradient norm: 0.4900054633617401
# Layer 1 gradient norm: 0.05382974073290825
# Layer 2 gradient norm: 0.5555393099784851
# Layer 3 gradient norm: 0.03568066284060478
# Layer 0 gradient norm: 0.4703305959701538
# Layer 1 gradient norm: 0.051701005548238754
# Layer 2 gradient norm: 0.5287914872169495
# Layer 3 gradient norm: 0.03412153571844101
# Layer 0 gradient norm: 0.4541136622428894
# Layer 1 gradient norm: 0.04995124414563179
# Layer 2 gradient norm: 0.5074149370193481
# Layer 3 gradient norm: 0.032871853560209274
# 1829/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9868 - loss: 0.0432Layer 0 gradient norm: 0.435636430978775
# Layer 1 gradient norm: 0.047950536012649536
# Layer 2 gradient norm: 0.4803354740142822
# Layer 3 gradient norm: 0.031309742480516434
# Layer 0 gradient norm: 0.41416141390800476
# Layer 1 gradient norm: 0.04566679149866104
# Layer 2 gradient norm: 0.4543667137622833
# Layer 3 gradient norm: 0.029819970950484276
# Layer 0 gradient norm: 0.40039244294166565
# Layer 1 gradient norm: 0.044331397861242294
# Layer 2 gradient norm: 0.43679848313331604
# Layer 3 gradient norm: 0.029013503342866898
# 1832/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9868 - loss: 0.0432Layer 0 gradient norm: 0.38695088028907776
# Layer 1 gradient norm: 0.04290791228413582
# Layer 2 gradient norm: 0.42290371656417847
# Layer 3 gradient norm: 0.028390586376190186
# Layer 0 gradient norm: 0.38233432173728943
# Layer 1 gradient norm: 0.042500052601099014
# Layer 2 gradient norm: 0.41591212153434753
# Layer 3 gradient norm: 0.028099091723561287
# 1834/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9868 - loss: 0.0432Layer 0 gradient norm: 0.37792685627937317
# Layer 1 gradient norm: 0.0421132929623127
# Layer 2 gradient norm: 0.4095005691051483
# Layer 3 gradient norm: 0.027833711355924606
# Layer 0 gradient norm: 0.3280913233757019
# Layer 1 gradient norm: 0.037278492003679276
# Layer 2 gradient norm: 0.3451399505138397
# Layer 3 gradient norm: 0.024688921868801117
# 1836/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9868 - loss: 0.0432Layer 0 gradient norm: 0.2997405230998993
# Layer 1 gradient norm: 0.034500956535339355
# Layer 2 gradient norm: 0.30593258142471313
# Layer 3 gradient norm: 0.022829217836260796
# Layer 0 gradient norm: 0.2881331741809845
# Layer 1 gradient norm: 0.0335717648267746
# Layer 2 gradient norm: 0.28373056650161743
# Layer 3 gradient norm: 0.021784676238894463
# Layer 0 gradient norm: 0.28413334488868713
# Layer 1 gradient norm: 0.03336144983768463
# Layer 2 gradient norm: 0.27143484354019165
# Layer 3 gradient norm: 0.021178508177399635
# 1839/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9868 - loss: 0.0432Layer 0 gradient norm: 0.2852281332015991
# Layer 1 gradient norm: 0.033642202615737915
# Layer 2 gradient norm: 0.2661181688308716
# Layer 3 gradient norm: 0.020924804732203484
# Layer 0 gradient norm: 0.28358685970306396
# Layer 1 gradient norm: 0.0335417278110981
# Layer 2 gradient norm: 0.2604341208934784
# Layer 3 gradient norm: 0.02052418515086174
# Layer 0 gradient norm: 0.27567052841186523
# Layer 1 gradient norm: 0.03261585906147957
# Layer 2 gradient norm: 0.24820122122764587
# Layer 3 gradient norm: 0.019569749012589455
# 1842/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9868 - loss: 0.0432Layer 0 gradient norm: 0.2660576105117798
# Layer 1 gradient norm: 0.03149574622511864
# Layer 2 gradient norm: 0.2418460100889206
# Layer 3 gradient norm: 0.01905054785311222
# Layer 0 gradient norm: 0.26077374815940857
# Layer 1 gradient norm: 0.030869344249367714
# Layer 2 gradient norm: 0.23549319803714752
# Layer 3 gradient norm: 0.01854679547250271
# Layer 0 gradient norm: 0.2562786638736725
# Layer 1 gradient norm: 0.030337290838360786
# Layer 2 gradient norm: 0.23060199618339539
# Layer 3 gradient norm: 0.01817094162106514
# 1845/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9868 - loss: 0.0432Layer 0 gradient norm: 0.24661174416542053
# Layer 1 gradient norm: 0.029219597578048706
# Layer 2 gradient norm: 0.22151592373847961
# Layer 3 gradient norm: 0.017493395134806633
# Layer 0 gradient norm: 0.23807787895202637
# Layer 1 gradient norm: 0.0282403863966465
# Layer 2 gradient norm: 0.21364657580852509
# Layer 3 gradient norm: 0.016916226595640182
# Layer 0 gradient norm: 0.2304602861404419
# Layer 1 gradient norm: 0.027374040335416794
# Layer 2 gradient norm: 0.2066744714975357
# Layer 3 gradient norm: 0.016409074887633324
# 1848/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9868 - loss: 0.0432Layer 0 gradient norm: 0.21461842954158783
# Layer 1 gradient norm: 0.025563327595591545
# Layer 2 gradient norm: 0.19196926057338715
# Layer 3 gradient norm: 0.015340662561357021
# Layer 0 gradient norm: 0.19956889748573303
# Layer 1 gradient norm: 0.023827653378248215
# Layer 2 gradient norm: 0.1780828982591629
# Layer 3 gradient norm: 0.014315228909254074
# Layer 0 gradient norm: 0.18555685877799988
# Layer 1 gradient norm: 0.02224399708211422
# Layer 2 gradient norm: 0.15829479694366455
# Layer 3 gradient norm: 0.012808922678232193
# 1851/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9868 - loss: 0.0432Layer 0 gradient norm: 0.1663312166929245
# Layer 1 gradient norm: 0.020092474296689034
# Layer 2 gradient norm: 0.14167766273021698
# Layer 3 gradient norm: 0.011552288196980953
# Layer 0 gradient norm: 0.14924578368663788
# Layer 1 gradient norm: 0.018158046528697014
# Layer 2 gradient norm: 0.12714843451976776
# Layer 3 gradient norm: 0.010445401072502136
# Layer 0 gradient norm: 0.1404256522655487
# Layer 1 gradient norm: 0.017192546278238297
# Layer 2 gradient norm: 0.11977771669626236
# Layer 3 gradient norm: 0.009889106266200542
# 1854/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9868 - loss: 0.0432Layer 0 gradient norm: 0.13197559118270874
# Layer 1 gradient norm: 0.01623697206377983
# Layer 2 gradient norm: 0.11257491260766983
# Layer 3 gradient norm: 0.009331903420388699
# Layer 0 gradient norm: 0.12607921659946442
# Layer 1 gradient norm: 0.01564856804907322
# Layer 2 gradient norm: 0.1075814813375473
# Layer 3 gradient norm: 0.008963978849351406
# Layer 0 gradient norm: 0.12216202169656754
# Layer 1 gradient norm: 0.01526658795773983
# Layer 2 gradient norm: 0.10423742979764938
# Layer 3 gradient norm: 0.00872899778187275
# 1857/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9868 - loss: 0.0432Layer 0 gradient norm: 0.12203371524810791
# Layer 1 gradient norm: 0.015328692272305489
# Layer 2 gradient norm: 0.10414594411849976
# Layer 3 gradient norm: 0.008745536208152771
# Layer 0 gradient norm: 0.12189962714910507
# Layer 1 gradient norm: 0.015344856306910515
# Layer 2 gradient norm: 0.1038597896695137
# Layer 3 gradient norm: 0.008738499134778976
# 1859/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9868 - loss: 0.0432Layer 0 gradient norm: 0.12131144106388092
# Layer 1 gradient norm: 0.015268308110535145
# Layer 2 gradient norm: 0.10329199582338333
# Layer 3 gradient norm: 0.008695854805409908
# Layer 0 gradient norm: 0.12113571912050247
# Layer 1 gradient norm: 0.015249848365783691
# Layer 2 gradient norm: 0.10292372852563858
# Layer 3 gradient norm: 0.008670133538544178
# Layer 0 gradient norm: 0.12688636779785156
# Layer 1 gradient norm: 0.01583278365433216
# Layer 2 gradient norm: 0.10766139626502991
# Layer 3 gradient norm: 0.009036536328494549
# 1862/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9868 - loss: 0.0432Layer 0 gradient norm: 0.1335931420326233
# Layer 1 gradient norm: 0.016617245972156525
# Layer 2 gradient norm: 0.11323180794715881
# Layer 3 gradient norm: 0.009496144950389862
# Layer 0 gradient norm: 0.1400628387928009
# Layer 1 gradient norm: 0.017342999577522278
# Layer 2 gradient norm: 0.11863812059164047
# Layer 3 gradient norm: 0.009938318282365799
# Layer 0 gradient norm: 0.15038618445396423
# Layer 1 gradient norm: 0.01860661804676056
# Layer 2 gradient norm: 0.12744452059268951
# Layer 3 gradient norm: 0.010662233456969261
# 1865/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9868 - loss: 0.0432Layer 0 gradient norm: 0.16042135655879974
# Layer 1 gradient norm: 0.01988546922802925
# Layer 2 gradient norm: 0.1354171335697174
# Layer 3 gradient norm: 0.011317283846437931
# Layer 0 gradient norm: 0.17299601435661316
# Layer 1 gradient norm: 0.021401314064860344
# Layer 2 gradient norm: 0.14615929126739502
# Layer 3 gradient norm: 0.012188879773020744
# Layer 0 gradient norm: 0.19007617235183716
# Layer 1 gradient norm: 0.023518752306699753
# Layer 2 gradient norm: 0.16061782836914062
# Layer 3 gradient norm: 0.013392409309744835
# 1868/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9868 - loss: 0.0432Layer 0 gradient norm: 0.2095944732427597
# Layer 1 gradient norm: 0.0260063037276268
# Layer 2 gradient norm: 0.17733103036880493
# Layer 3 gradient norm: 0.014793959446251392
# Layer 0 gradient norm: 0.22952298820018768
# Layer 1 gradient norm: 0.02853097766637802
# Layer 2 gradient norm: 0.19429777562618256
# Layer 3 gradient norm: 0.01621800847351551
# Layer 0 gradient norm: 0.2500580847263336
# Layer 1 gradient norm: 0.03111542947590351
# Layer 2 gradient norm: 0.2117949277162552
# Layer 3 gradient norm: 0.017684223130345345
# 1871/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9868 - loss: 0.0432Layer 0 gradient norm: 0.27110007405281067
# Layer 1 gradient norm: 0.03397303819656372
# Layer 2 gradient norm: 0.23005211353302002
# Layer 3 gradient norm: 0.019256876781582832
# Layer 0 gradient norm: 0.2816101014614105
# Layer 1 gradient norm: 0.035341355949640274
# Layer 2 gradient norm: 0.23904001712799072
# Layer 3 gradient norm: 0.02002996951341629
# Layer 0 gradient norm: 0.2790759205818176
# Layer 1 gradient norm: 0.035011421889066696
# Layer 2 gradient norm: 0.2383660227060318
# Layer 3 gradient norm: 0.019966071471571922
# 1874/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9868 - loss: 0.0432Layer 0 gradient norm: 0.27777794003486633
# Layer 1 gradient norm: 0.0348607636988163
# Layer 2 gradient norm: 0.2374555915594101
# Layer 3 gradient norm: 0.01987580955028534
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 82s 24ms/step - accuracy: 0.9868 - loss: 0.0432 - val_accuracy: 0.9745 - val_loss: 0.0831
